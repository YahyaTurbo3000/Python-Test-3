# %%
numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
person = {"name": "Alice", "age": 25}
print(person["name"])
# Out:
# Alice

# %%
colors = {"red", "green", "blue"}
colors.add("yellow")
print(colors)
# Out:
# {'yellow', 'green', 'red', 'blue'}

# %%
numbers = [1, 2, 3, 4, 5]
doubled = map(lambda x: x * 2, numbers)
print(doubled)
# I cant do this

# %%
df = {
    "Ali": 80,
    "Sara": 94,
    "Farhan": 74,
    "Rizwan": 50,
    "Rehan" : 43,
}
print(df)
# Out:
# {'Ali': 80, 'Sara': 94, 'Farhan': 74, 'Rizwan': 50, 'Rehan': 43}

# %%
sum = 0
for i in df:
    de = df[i]
    print(de)
    sum = sum + de

sum = sum / 5
print(sum)
# Out:
# 80
# 94
# 74
# 50
# 43
# 68.2

# %%
a = input("What student would you like the score of?: ")
b = df.get(a)
if a in df:
    print(b)
if a not in df:
    print("Student not found")
# Out:
# Student not found
